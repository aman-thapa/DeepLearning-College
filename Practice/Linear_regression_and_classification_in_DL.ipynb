# %%
import numpy as np
import pandas as pd
import os
from tensorflow.keras.utils import to_categorical

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-86a6e974-fc25-437a-a59c-2f3ed0a04514" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86a6e974-fc25-437a-a59c-2f3ed0a04514">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris.csv

# %%
pd.read_csv("Iris.csv")
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
dataset = pd.read_csv('Iris.csv')

dataset
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
X = dataset.iloc[:,1:5].values
y = dataset.iloc[:,5].values

from sklearn.preprocessing import LabelEncoder
encoder =  LabelEncoder()
y1 = encoder.fit_transform(y)

Y = pd.get_dummies(y1).values

from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import SGD, Adam


model = Sequential()

model.add(Dense(10,input_shape=(4,),activation='tanh'))
model.add(Dense(8,activation='tanh'))
model.add(Dense(6,activation='tanh'))
model.add(Dense(3,activation='softmax'))

model.compile(Adam(lr=0.04),'categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 10)                50
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 54
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 21
# =================================================================
# Total params: 213
# Trainable params: 213
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
model.fit(X_train,y_train,epochs=100)
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 3ms/step - loss: 1.1687 - accuracy: 0.3333
# Epoch 2/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0721 - accuracy: 0.4083
# Epoch 3/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9087 - accuracy: 0.5833
# Epoch 4/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6892 - accuracy: 0.6917
# Epoch 5/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5466 - accuracy: 0.7000
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4799 - accuracy: 0.7750
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4319 - accuracy: 0.8333
# Epoch 8/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3383 - accuracy: 0.9167
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2940 - accuracy: 0.9000
# Epoch 10/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1381 - accuracy: 0.9833
# Epoch 11/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2761 - accuracy: 0.9000
# Epoch 12/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2502 - accuracy: 0.9167
# Epoch 13/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2337 - accuracy: 0.9083
# Epoch 14/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1282 - accuracy: 0.9417
# Epoch 15/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1422 - accuracy: 0.9417
# Epoch 16/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0990 - accuracy: 0.9667
# Epoch 17/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1114 - accuracy: 0.9500
# Epoch 18/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1349 - accuracy: 0.9417
# Epoch 19/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0931 - accuracy: 0.9750
# Epoch 20/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0921 - accuracy: 0.9750
# Epoch 21/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0904 - accuracy: 0.9583
# Epoch 22/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0711 - accuracy: 0.9750
# Epoch 23/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0683 - accuracy: 0.9833
# Epoch 24/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0691 - accuracy: 0.9833
# Epoch 25/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0678 - accuracy: 0.9667
# Epoch 26/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0712 - accuracy: 0.9750
# Epoch 27/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0931 - accuracy: 0.9667
# Epoch 28/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0966 - accuracy: 0.9750
# Epoch 29/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0828 - accuracy: 0.9750
# Epoch 30/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1000 - accuracy: 0.9667
# Epoch 31/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0742 - accuracy: 0.9750
# Epoch 32/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.9833
# Epoch 33/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0713 - accuracy: 0.9833
# Epoch 34/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.9667
# Epoch 35/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0647 - accuracy: 0.9750
# Epoch 36/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0694 - accuracy: 0.9750
# Epoch 37/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0834 - accuracy: 0.9667
# Epoch 38/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0787 - accuracy: 0.9667
# Epoch 39/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 0.9750
# Epoch 40/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0642 - accuracy: 0.9833
# Epoch 41/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0634 - accuracy: 0.9750
# Epoch 42/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0646 - accuracy: 0.9750
# Epoch 43/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1261 - accuracy: 0.9500
# Epoch 44/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1952 - accuracy: 0.9083
# Epoch 45/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1625 - accuracy: 0.9250
# Epoch 46/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1025 - accuracy: 0.9750
# Epoch 47/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0862 - accuracy: 0.9583
# Epoch 48/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0816 - accuracy: 0.9750
# Epoch 49/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0898 - accuracy: 0.9583
# Epoch 50/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0670 - accuracy: 0.9750
# Epoch 51/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0553 - accuracy: 0.9917
# Epoch 52/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1265 - accuracy: 0.9583
# Epoch 53/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0516 - accuracy: 0.9833
# Epoch 54/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0870 - accuracy: 0.9583
# Epoch 55/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.9417
# Epoch 56/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1445 - accuracy: 0.9417
# Epoch 57/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1023 - accuracy: 0.9667
# Epoch 58/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0822 - accuracy: 0.9583
# Epoch 59/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0915 - accuracy: 0.9500
# Epoch 60/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0952 - accuracy: 0.9667
# Epoch 61/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1283 - accuracy: 0.9583
# Epoch 62/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0890 - accuracy: 0.9667
# Epoch 63/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0865 - accuracy: 0.9667
# Epoch 64/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1028 - accuracy: 0.9500
# Epoch 65/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0831 - accuracy: 0.9750
# Epoch 66/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0954 - accuracy: 0.9500
# Epoch 67/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0598 - accuracy: 0.9750
# Epoch 68/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1092 - accuracy: 0.9500
# Epoch 69/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0812 - accuracy: 0.9583
# Epoch 70/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0727 - accuracy: 0.9667
# Epoch 71/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 0.9833
# Epoch 72/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0607 - accuracy: 0.9750
# Epoch 73/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0862 - accuracy: 0.9750
# Epoch 74/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2373 - accuracy: 0.9250
# Epoch 75/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1074 - accuracy: 0.9500
# Epoch 76/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1120 - accuracy: 0.9583
# Epoch 77/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1006 - accuracy: 0.9667
# Epoch 78/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0902 - accuracy: 0.9583
# Epoch 79/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0610 - accuracy: 0.9750
# Epoch 80/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0846 - accuracy: 0.9750
# Epoch 81/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0678 - accuracy: 0.9750
# Epoch 82/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0981 - accuracy: 0.9667
# Epoch 83/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0597 - accuracy: 0.9750
# Epoch 84/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0670 - accuracy: 0.9750
# Epoch 85/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0676 - accuracy: 0.9583
# Epoch 86/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9667
# Epoch 87/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0610 - accuracy: 0.9833
# Epoch 88/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 0.9750
# Epoch 89/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1434 - accuracy: 0.9583
# Epoch 90/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1125 - accuracy: 0.9583
# Epoch 91/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0885 - accuracy: 0.9750
# Epoch 92/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1079 - accuracy: 0.9583
# Epoch 93/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0825 - accuracy: 0.9833
# Epoch 94/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0994 - accuracy: 0.9583
# Epoch 95/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0540 - accuracy: 0.9750
# Epoch 96/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0582 - accuracy: 0.9750
# Epoch 97/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0597 - accuracy: 0.9667
# Epoch 98/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0577 - accuracy: 0.9833
# Epoch 99/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0839 - accuracy: 0.9583
# Epoch 100/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1213 - accuracy: 0.9500

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00         6
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]
